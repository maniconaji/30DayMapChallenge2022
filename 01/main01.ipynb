# %%
import osmnx as ox
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

from sqlalchemy import create_engine

# %%
gdf = ox.geometries_from_place('Austria', {'place':'city'}).to_crs("epsg:4326").reset_index(drop=True)[["name", "geometry"]]
gdf.head(7)
# Out:
#          name                                           geometry
# 0  Klagenfurt                          POINT (14.30760 46.62394)
# 1        Linz                          POINT (14.28620 48.30591)
# 2        Graz                          POINT (15.43828 47.07087)
# 3        Wien                          POINT (16.37250 48.20835)
# 4  Bratislava  MULTIPOLYGON (((17.02860 48.19776, 17.02819 48...
# 5    Salzburg                          POINT (13.04648 47.79813)
# 6   Innsbruck                          POINT (11.39277 47.26543)

# %%
gdf_tourism = []
for city in gdf['name']:
    if city == 'Wien':
        city = "Vienna"
    if city != "Bratislava":
        gdf_sub = ox.geometries_from_address(city+', Austria', {'tourism': 'museum'}).to_crs("epsg:4326").reset_index(drop=True)
        #
        cond = (gdf_sub["geometry"].geom_type == 'Polygon') | (gdf_sub["geometry"].geom_type == 'MultiPolygon')
        gdf_sub.loc[cond, "geometry"] = gdf_sub.loc[cond, "geometry"].to_crs("proj=+cea").centroid.to_crs("epsg:4326")
        #
        gdf_tourism.append(gdf_sub)
        print(city)
gdf_tourism = pd.concat(gdf_tourism)
gdf_tourism.head()
# Out:
# Klagenfurt
# Linz
# Graz
# Vienna
# Salzburg
# Innsbruck
#                             name tourism wheelchair  \
# 0          Thomas-Koschat-Museum  museum         no
# 1  Museum Moderner Kunst Kärnten  museum        yes
# 2                   Eboardmuseum  museum        yes
# 3                 Diözesanmuseum  museum         no
# 4                   Landesarchiv  museum        NaN
#
#                           wikipedia                   geometry  \
# 0                 de:Thomas_Koschat  POINT (14.31049 46.62032)
# 1  de:Museum Moderner Kunst Kärnten  POINT (14.31013 46.62417)
# 2                   de:Eboardmuseum  POINT (14.30493 46.61649)
# 3                               NaN  POINT (14.30938 46.62235)
# 4                               NaN  POINT (14.30787 46.61824)
#
#                   addr:city addr:country addr:housenumber addr:postcode  \
# 0                       NaN          NaN              NaN           NaN
# 1  Klagenfurt am Wörthersee           AT                8          9021
# 2  Klagenfurt am Wörthersee           AT               20          9020
# 3  Klagenfurt am Wörthersee           AT             10/3          9020
# 4  Klagenfurt am Wörthersee           AT                7           NaN
#
#              addr:street  ... building:part roof:colour roof:height  \
# 0                    NaN  ...           NaN         NaN         NaN
# 1              Burggasse  ...           NaN         NaN         NaN
# 2  Florian-Gröger-Straße  ...           NaN         NaN         NaN
# 3         Lidmanskygasse  ...           NaN         NaN         NaN
# 4  St. Ruprechter Straße  ...           NaN         NaN         NaN
#
#   building:levels:underground name:old int_name name:ar addr:suburb  url  \
# 0                         NaN      NaN      NaN     NaN         NaN  NaN
# 1                         NaN      NaN      NaN     NaN         NaN  NaN
# 2                         NaN      NaN      NaN     NaN         NaN  NaN
# 3                         NaN      NaN      NaN     NaN         NaN  NaN
# 4                         NaN      NaN      NaN     NaN         NaN  NaN
#
#   ref:isil
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 148 columns]

# %%
gdf_tourism
# Out:
#                              name tourism wheelchair  \
# 0           Thomas-Koschat-Museum  museum         no
# 1   Museum Moderner Kunst Kärnten  museum        yes
# 2                    Eboardmuseum  museum        yes
# 3                  Diözesanmuseum  museum         no
# 4                    Landesarchiv  museum        NaN
# ..                            ...     ...        ...
# 5                     Audioversum  museum        yes
# 6            Galerie Mathias Mayr  museum        NaN
# 7                             AUT  museum        yes
# 8       Landesmuseum Ferdinandeum  museum        NaN
# 9                Volkskunstmuseum  museum        NaN
#
#                            wikipedia                   geometry  \
# 0                  de:Thomas_Koschat  POINT (14.31049 46.62032)
# 1   de:Museum Moderner Kunst Kärnten  POINT (14.31013 46.62417)
# 2                    de:Eboardmuseum  POINT (14.30493 46.61649)
# 3                                NaN  POINT (14.30938 46.62235)
# 4                                NaN  POINT (14.30787 46.61824)
# ..                               ...                        ...
# 5                                NaN  POINT (11.39678 47.26347)
# 6                                NaN  POINT (11.38853 47.26806)
# 7                                NaN  POINT (11.39941 47.26105)
# 8            de:Tiroler Landesmuseum  POINT (11.39773 47.26733)
# 9        de:Tiroler Volkskunstmuseum  POINT (11.39570 47.26826)
#
#                    addr:city addr:country addr:housenumber addr:postcode  \
# 0                        NaN          NaN              NaN           NaN
# 1   Klagenfurt am Wörthersee           AT                8          9021
# 2   Klagenfurt am Wörthersee           AT               20          9020
# 3   Klagenfurt am Wörthersee           AT             10/3          9020
# 4   Klagenfurt am Wörthersee           AT                7           NaN
# ..                       ...          ...              ...           ...
# 5                  Innsbruck           AT               23          6020
# 6                        NaN          NaN              NaN           NaN
# 7                  Innsbruck           AT                1          6020
# 8                  Innsbruck           AT               15          6020
# 9                  Innsbruck           AT                2          6020
#
#                 addr:street  ... building:part roof:colour roof:height  \
# 0                       NaN  ...           NaN         NaN         NaN
# 1                 Burggasse  ...           NaN         NaN         NaN
# 2     Florian-Gröger-Straße  ...           NaN         NaN         NaN
# 3            Lidmanskygasse  ...           NaN         NaN         NaN
# 4     St. Ruprechter Straße  ...           NaN         NaN         NaN
# ..                      ...  ...           ...         ...         ...
# 5      Wilhelm-Greil-Straße  ...           NaN         NaN         NaN
# 6                       NaN  ...           NaN         NaN         NaN
# 7   Lois-Welzenbacher-Platz  ...           NaN         NaN         NaN
# 8              Museumstraße  ...           NaN         NaN         NaN
# 9        Universitätsstraße  ...           NaN        grey         NaN
#
#    building:levels:underground name:old int_name name:ar addr:suburb  url  \
# 0                          NaN      NaN      NaN     NaN         NaN  NaN
# 1                          NaN      NaN      NaN     NaN         NaN  NaN
# 2                          NaN      NaN      NaN     NaN         NaN  NaN
# 3                          NaN      NaN      NaN     NaN         NaN  NaN
# 4                          NaN      NaN      NaN     NaN         NaN  NaN
# ..                         ...      ...      ...     ...         ...  ...
# 5                          NaN      NaN      NaN     NaN         NaN  NaN
# 6                          NaN      NaN      NaN     NaN         NaN  NaN
# 7                          NaN      NaN      NaN     NaN      Wilten  NaN
# 8                          NaN      NaN      NaN     NaN         NaN  NaN
# 9                          NaN      NaN      NaN     NaN         NaN  NaN
#
#    ref:isil
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 5       NaN
# 6       NaN
# 7       NaN
# 8   AT-FERD
# 9       NaN
#
# [121 rows x 148 columns]

# %%
gdf_tourism["geometry"].geom_type.unique()
# Out:
# array(['Point'], dtype=object)

# %%
host = "localhost"
database = "30DayMapChallenge2022"
user = os.getenv('SQL_USER')
password = os.getenv('SQL_PASSWORD')

# %%
engine = create_engine(f"postgresql://{user}:{password}@{host}/{database}")

# %%
gdf_tourism.to_postgis("museums_austria", engine, if_exists='replace')

# %%
gdf.to_postgis("city_austria", engine, if_exists='replace')
